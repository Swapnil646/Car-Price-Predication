# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("car data.csv")

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# Basic Checks
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.shape
# Out:
# (301, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# Encoding
data.replace({"Fuel_Type ":{"Petrol":0,"Diesel":1,"CNG":2}},inplace=True)

# %%
data.replace({"Seller_Type ":{"Dealer":0,"Individual":1}},inplace=True)

# %%
data.replace({"Transmission ":{"Maunal":0,"Automatic":1}},inplace=True)

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# label Encoding :- Categorical data to Numerical data
from sklearn.preprocessing  import LabelEncoder
cols=["Fuel_Type","Seller_Type","Transmission"]
le=LabelEncoder()

for col in cols:
    data[col]=le.fit_transform(data[col])

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             1      0
# 1            0             1      0
# 2            0             1      0
# 3            0             1      0
# 4            0             1      0

# %%
data.drop("Car_Name",axis=1,inplace=True)

# %%
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0    2014           3.35           5.59       27000          2            0
# 1    2013           4.75           9.54       43000          1            0
# 2    2017           7.25           9.85        6900          2            0
# 3    2011           2.85           4.15        5200          2            0
# 4    2014           4.60           6.87       42450          1            0
# ..    ...            ...            ...         ...        ...          ...
# 296  2016           9.50          11.60       33988          1            0
# 297  2015           4.00           5.90       60000          2            0
# 298  2009           3.35          11.00       87934          2            0
# 299  2017          11.50          12.50        9000          1            0
# 300  2016           5.30           5.90        5464          2            0
#
#      Transmission  Owner
# 0               1      0
# ...

# %%
# data Preprocessing

# %%
data.isnull().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 2

# %%
# Check The Outliers

# %%
plt.figure(figsize=(20,25),facecolor="white")
plotnumber=1
for column in data.drop("Selling_Price",axis=1):
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(x=data[column])
        plt.xlabel(column,fontsize=10)
        plt.ylabel("count",fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# handle in outliers
plotnumber=1
for column in data :
    if plotnumber<=31:
        #find Q1 & Q3
        Q1=data[column].quantile(0.25)
        print('lower quartile',Q1)
        Q3=data[column].quantile(0.75)
        print('upper quartile',Q3)
        #finding interquartile range
        IQR=Q3-Q1
        IQR
        #find lower limit and upper limit
        lower_limit=Q1-1.5*IQR
        print('lower_limit',lower_limit)
        upper_limit=Q3+1.5*IQR
        print('upper_limit:',upper_limit)
        #find values above upper_limit & lower_limit
        print(data.loc[data[column]>upper_limit])
        print(data.loc[data[column]<lower_limit])
        data.loc[data[column]>upper_limit,column]=data[column].median()
        data.loc[data[column]<lower_limit,column]=data[column].median()
    plotnumber+=1
# Out:
# lower quartile 2012.0
# upper quartile 2016.0
# lower_limit 2006.0
# upper_limit: 2022.0
# Empty DataFrame
# Columns: [Year, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner]
# Index: []
#      Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 37   2003           0.35           2.28      127000          2            1
# 39   2003           2.25           7.98       62000          2            0
# 54   2005           2.75          10.21       90000          2            1
# 77   2004           1.50          12.35      135154          2            0
# 84   2005           3.49          13.46      197176          1            0
# 92   2005           3.51          13.70       75000          2            0
# 189  2005           0.20           0.57       55000          2            1
#
#      Transmission  Owner
# 37              1      0
# 39              1      0
# 54              1      0
# 77              0      0
# ...

# %%
plt.figure(figsize=(20,25),facecolor="white")
plotnumber=1
for column in data.drop("Selling_Price",axis=1):
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(x=data[column])
        plt.xlabel(column,fontsize=10)
        plt.ylabel("count",fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# Corrrlation
data.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Year           1.000000       0.262137      -0.016855   -0.538325        NaN
# Selling_Price  0.262137       1.000000       0.788456    0.153939        NaN
# Present_Price -0.016855       0.788456       1.000000    0.381602        NaN
# Kms_Driven    -0.538325       0.153939       0.381602    1.000000        NaN
# Fuel_Type           NaN            NaN            NaN         NaN        NaN
# Seller_Type   -0.032041      -0.735550      -0.738417   -0.351171        NaN
# Transmission        NaN            NaN            NaN         NaN        NaN
# Owner               NaN            NaN            NaN         NaN        NaN
#
#                Seller_Type  Transmission  Owner
# Year             -0.032041           NaN    NaN
# Selling_Price    -0.735550           NaN    NaN
# Present_Price    -0.738417           NaN    NaN
# Kms_Driven       -0.351171           NaN    NaN
# ...

# %%
sns.heatmap(data.drop("Selling_Price",axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %%
# split data into x and y
x=data.drop("Selling_Price",axis=1)
y=data[["Selling_Price"]]

# %%
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          2            0             1
# 1    2013           9.54       43000          2            0             1
# 2    2017           9.85        6900          2            0             1
# 3    2011           4.15        5200          2            0             1
# 4    2014           6.87       42450          2            0             1
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          2            0             1
# 297  2015           5.90       60000          2            0             1
# 298  2009          11.00       87934          2            0             1
# 299  2017          12.50        9000          2            0             1
# 300  2016           5.90        5464          2            0             1
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
y
# Out:
#      Selling_Price
# 0             3.35
# 1             4.75
# 2             7.25
# 3             2.85
# 4             4.60
# ..             ...
# 296           9.50
# 297           4.00
# 298           3.35
# 299          11.50
# 300           5.30
#
# [301 rows x 1 columns]

# %%
# train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=3)

# %%
x_train.shape
# Out:
# (210, 7)

# %%
y_train.shape
# Out:
# (210, 1)

# %%
x_test.shape
# Out:
# (91, 7)

# %%
y_test.shape
# Out:
# (91, 1)

# %%
#Model Building
# import linear Regression model
from sklearn.linear_model import LinearRegression
# initialise model
model = LinearRegression()
# train model with x_train and y_train
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[ 1.193746  ],
#        [ 5.37674919],
#        [ 5.21969805],
#        [ 3.4176387 ],
#        [-1.22810152],
#        [ 7.16923903],
#        [ 5.69797159],
#        [ 1.91549119],
#        [ 6.23946119],
#        [ 4.75901773],
#        [ 7.77070911],
#        [-0.38232332],
#        [ 4.10682483],
#        [ 1.87205817],
#        [ 6.55862918],
#        [ 7.57071409],
#        [ 0.8580696 ],
#        [ 3.03587996],
#        [ 2.9786979 ],
#        [ 1.65107842],
#        [-1.34225642],
#        [ 3.41751473],
#        [ 1.34842322],
#        [-0.56855243],
#        [ 1.74143946],
#        [ 5.02092975],
#        [ 8.33210155],
#        [ 8.05473884],
#        [ 5.71940551],
#        [ 1.18300656],
#        [ 4.66570975],
#        [ 7.19532273],
#        [ 2.19805752],
#        [ 1.34331851],
#        [ 4.55869362],
#        [ 4.62259204],
#        [ 4.92315693],
#        [ 3.96446176],
#        [ 5.24336572],
#        [ 1.59380504],
#        [ 7.14733102],
# ...

# %%
y_test
# Out:
#      Selling_Price
# 151           0.50
# 214           5.25
# 251           5.00
# 25            3.00
# 194           0.20
# ..             ...
# 15            7.75
# 102           1.65
# 168           0.42
# 134           0.65
# 103           1.45
#
# [91 rows x 1 columns]

# %%
# slopes/coefficient of x
model.coef_
# Out:
# array([[ 2.88140179e-01,  3.25962377e-01, -1.02094298e-05,
#          0.00000000e+00, -2.10501691e+00,  0.00000000e+00,
#          0.00000000e+00]])

# %%
#intercept
model.intercept_
# Out:
# array([-577.45462505])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
#MSE
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 2.005894983396692

# %%
#MAE
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 1.0212695351764356

# %%
#RMSE
RMSE=np.sqrt(MSE)
RMSE
# Out:
# 1.416296220215493

# %%
# R2-score
r2_score(y_test,y_pred)
# Out:
# 0.7279799539642207

# %%
y_test.shape
# Out:
# (91, 1)

# %%
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0    2014           3.35           5.59       27000          2            0
# 1    2013           4.75           9.54       43000          2            0
# 2    2017           7.25           9.85        6900          2            0
# 3    2011           2.85           4.15        5200          2            0
# 4    2014           4.60           6.87       42450          2            0
# ..    ...            ...            ...         ...        ...          ...
# 296  2016           9.50          11.60       33988          2            0
# 297  2015           4.00           5.90       60000          2            0
# 298  2009           3.35          11.00       87934          2            0
# 299  2017          11.50          12.50        9000          2            0
# 300  2016           5.30           5.90        5464          2            0
#
#      Transmission  Owner
# 0               1      0
# ...

# %%
# adjusted_r2 score
adj_r2=1-(1-0.73)*(91-1)/(91-7-1)
adj_r2
# Out:
# 0.7072289156626506
